# %% [markdown]
# <a href="https://colab.research.google.com/github/sreedharsiddhu/Project_ML-/blob/main/Working_project_ML_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Airport1 = pd.read_excel("/content/Grazzanise airport.xlsx")
AirportC1 = Airport1

# %%
Airport2 = pd.read_excel("/content/Trapani airport.xlsx")
AirportC2 = Airport2

# %%
Airport3 = pd.read_excel("/content/Treviso airport.xlsx")
AirportC3 = Airport3

# %%
AirportC1 = Airport1
AirportC2 = Airport2
AirportC3 = Airport3

# %%
Airport1
# Out:
#                    date  idstazione    lon    lat  altezza  pressure  \
# 0      14/03/1996 12:00       16253  14.07  41.05       10  100790.0
# 1      16/01/1997 18:00       16253  14.07  41.05       10  102290.0
# 2      19/06/1997 06:00       16253  14.07  41.05       10  100850.0
# 3      30/05/1998 18:00       16253  14.07  41.05       10  101520.0
# 4      15/12/1998 21:00       16253  14.07  41.05       10  102580.0
# ...                 ...         ...    ...    ...      ...       ...
# 69186  17/11/2023 19:00       16253  14.08  41.06       10  101060.0
# 69187  17/11/2023 20:00       16253  14.08  41.06       10  101100.0
# 69188  17/11/2023 21:00       16253  14.08  41.06       10  101190.0
# 69189  17/11/2023 22:00       16253  14.08  41.06       10  101220.0
# 69190  17/11/2023 23:00       16253  14.08  41.06       10  101310.0
#
#        three_hour_pressure_change  char_pressure_tendency  wind_direction  \
# 0                            20.0                     0.0            70.0
# 1                            20.0                     3.0             0.0
# 2                          -380.0                     6.0             0.0
# 3                            10.0                     0.0           260.0
# 4                            60.0                     1.0           100.0
# ...                           ...                     ...             ...
# 69186                        60.0                     3.0           280.0
# 69187                        70.0                     3.0           300.0
# 69188                       110.0                     2.0           320.0
# 69189                       160.0                     2.0           350.0
# 69190                       210.0                     2.0            10.0
#
#        wind_speed  relative_humidity  visibility  present_weather  \
# 0          7.7752                NaN     15000.0              2.0
# 1          0.0000                NaN      1800.0             10.0
# 2          0.0000                NaN      4500.0             10.0
# 3          5.8314                NaN     20000.0              2.0
# 4          3.8876                NaN      8000.0             10.0
# ...           ...                ...         ...              ...
# 69186      1.9438                NaN     11000.0              2.0
# 69187      3.8876                NaN     11000.0              2.0
# 69188      5.8314                NaN     11000.0              2.0
# 69189      7.7752                NaN     11000.0              2.0
# 69190     11.6628                NaN     11000.0              2.0
#
#        past_weather1  past_weather2  cloud_cover  height_of_base_of_cloud  \
# 0                1.0            1.0          6.0                   1750.0
# 1                0.0            0.0          1.0                    800.0
# 2                1.0            1.0          6.0                    800.0
# 3                1.0            1.0          4.0                   3500.0
# 4                0.0            0.0          0.0                      NaN
# ...              ...            ...          ...                      ...
# 69186            1.0            1.0          3.0                   3500.0
# 69187            1.0            1.0          3.0                   3500.0
# 69188            1.0            1.0          3.0                    800.0
# 69189            1.0            1.0          2.0                   3500.0
# 69190            1.0            1.0          0.0                      NaN
#
#        cloud_type  drybulb  dewpoint
# 0              35      NaN       NaN
# 1              31      NaN       NaN
# 2              38      NaN       NaN
# 3              30      NaN       NaN
# 4              62      NaN       NaN
# ...           ...      ...       ...
# 69186          30    15.25     12.75
# 69187          30    14.65     12.55
# 69188          31    13.85     11.75
# 69189          30    13.45     11.35
# 69190          62    13.05      5.45
#
# [69191 rows x 20 columns]

# %%
Airport2
# Out:
#                     date  idstazione    lon    lat  altezza  pressure  \
# 0       01/01/1996 00:00       16429  12.50  37.92        9  100270.0
# 1       01/01/1996 03:00       16429  12.50  37.92        9  100280.0
# 2       01/01/1996 06:00       16429  12.50  37.92        9  100310.0
# 3       01/01/1996 09:00       16429  12.50  37.92        9  100490.0
# 4       01/01/1996 12:00       16429  12.50  37.92        9  100520.0
# ...                  ...         ...    ...    ...      ...       ...
# 175661  18/11/2023 19:00       16429  12.49  37.91        9  102320.0
# 175662  18/11/2023 20:00       16429  12.49  37.91        9  102350.0
# 175663  18/11/2023 21:00       16429  12.49  37.91        9  102390.0
# 175664  18/11/2023 22:00       16429  12.49  37.91        9  102390.0
# 175665  18/11/2023 23:00       16429  12.49  37.91        9  102380.0
#
#         three_hour_pressure_change  char_pressure_tendency  wind_direction  \
# 0                             70.0                     1.0           270.0
# 1                             10.0                     3.0           270.0
# 2                             30.0                     3.0           270.0
# 3                            180.0                     1.0           270.0
# 4                             30.0                     0.0           280.0
# ...                            ...                     ...             ...
# 175661                       180.0                     1.0           100.0
# 175662                       170.0                     1.0            90.0
# 175663                       180.0                     1.0           110.0
# 175664                        70.0                     1.0           130.0
# 175665                        30.0                     1.0           150.0
#
#         wind_speed  relative_humidity  visibility  present_weather  \
# 0          15.5504                NaN     10000.0              2.0
# 1          17.4942                NaN     10000.0              2.0
# 2          13.6066                NaN     14000.0              2.0
# 3           9.7190                NaN     18000.0              2.0
# 4          13.6066                NaN     18000.0              2.0
# ...            ...                ...         ...              ...
# 175661      3.8876                NaN     12000.0              2.0
# 175662      3.8876                NaN     12000.0              2.0
# 175663      3.8876                NaN     12000.0              2.0
# 175664      1.9438                NaN     12000.0              2.0
# 175665      1.9438                NaN     12000.0              2.0
#
#         past_weather1  past_weather2  cloud_cover  height_of_base_of_cloud  \
# 0                 1.0            1.0          5.0                    450.0
# 1                 1.0            1.0          4.0                    250.0
# 2                 1.0            1.0          2.0                    450.0
# 3                 1.0            1.0          3.0                    800.0
# 4                 1.0            1.0          6.0                    800.0
# ...               ...            ...          ...                      ...
# 175661            1.0            1.0          0.0                      NaN
# 175662            1.0            1.0          0.0                      NaN
# 175663            1.0            1.0          0.0                      NaN
# 175664            1.0            1.0          0.0                      NaN
# 175665            1.0            1.0          0.0                      NaN
#
#         cloud_type  drybulb  dewpoint
# 0               35      NaN       NaN
# 1               35      NaN       NaN
# 2               35      NaN       NaN
# 3               35      NaN       NaN
# 4               35      NaN       NaN
# ...            ...      ...       ...
# 175661          62    14.05      9.15
# 175662          62    13.85      8.85
# 175663          62    12.25      8.95
# 175664          62    11.85      9.05
# 175665          62    12.05     10.15
#
# [175666 rows x 20 columns]

# %%
Airport3
# Out:
#                     date  idstazione    lon    lat  altezza  pressure  \
# 0       01/01/1996 00:00       16098  12.10  45.68       42   99090.0
# 1       01/01/1996 03:00       16098  12.10  45.68       42   99210.0
# 2       01/01/1996 06:00       16098  12.10  45.68       42   99330.0
# 3       01/01/1996 09:00       16098  12.10  45.68       42       NaN
# 4       01/01/1996 12:00       16098  12.10  45.68       42   99640.0
# ...                  ...         ...    ...    ...      ...       ...
# 174107  18/11/2023 19:00       16098  12.11  45.68       42  101760.0
# 174108  18/11/2023 20:00       16098  12.11  45.68       42  101830.0
# 174109  18/11/2023 21:00       16098  12.11  45.68       42  101800.0
# 174110  18/11/2023 22:00       16098  12.11  45.68       42  101800.0
# 174111  18/11/2023 23:00       16098  12.11  45.68       42  101770.0
#
#         three_hour_pressure_change  char_pressure_tendency  wind_direction  \
# 0                            100.0                     2.0            10.0
# 1                            120.0                     2.0             0.0
# 2                            120.0                     2.0            20.0
# 3                              NaN                     NaN             0.0
# 4                             20.0                     1.0            40.0
# ...                            ...                     ...             ...
# 174107                        10.0                     1.0            10.0
# 174108                        60.0                     2.0           360.0
# 174109                       100.0                     2.0            80.0
# 174110                        40.0                     3.0           120.0
# 174111                       -70.0                     8.0            10.0
#
#         wind_speed  relative_humidity  visibility  present_weather  \
# 0           5.8314                NaN      4000.0             10.0
# 1           1.9438                NaN      3000.0             50.0
# 2           1.9438                NaN      2500.0             60.0
# 3           1.9438                NaN      2500.0              NaN
# 4           5.8314                NaN      8000.0             10.0
# ...            ...                ...         ...              ...
# 174107      5.8314                NaN     15000.0              2.0
# 174108      1.9438                NaN     15000.0              2.0
# 174109      3.8876                NaN     15000.0              2.0
# 174110      1.9438                NaN     15000.0              2.0
# 174111      1.9438                NaN     15000.0              2.0
#
#         past_weather1  past_weather2  cloud_cover  height_of_base_of_cloud  \
# 0                 6.0            5.0          8.0                    800.0
# 1                 5.0            2.0          8.0                    450.0
# 2                 6.0            5.0          8.0                    450.0
# 3                 NaN            NaN          8.0                      NaN
# 4                 6.0            2.0          8.0                    800.0
# ...               ...            ...          ...                      ...
# 174107            1.0            1.0          1.0                   2250.0
# 174108            1.0            1.0          0.0                      NaN
# 174109            1.0            1.0          1.0                   8000.0
# 174110            1.0            1.0          0.0                      NaN
# 174111            1.0            1.0          0.0                      NaN
#
#         cloud_type  drybulb  dewpoint
# 0               37      NaN       NaN
# 1               37      NaN       NaN
# 2               37      NaN       NaN
# 3               62      NaN       NaN
# 4               35      NaN       NaN
# ...            ...      ...       ...
# 174107          30     5.65      3.05
# 174108          62     4.85      2.55
# 174109          30     4.45      2.15
# 174110          62     3.65      2.05
# 174111          62     3.05      1.55
#
# [174112 rows x 20 columns]

# %% [markdown]
# Finding the missing Values in Airport 1

# %%
# Count the total number of missing values in Airport1
total_missing = Airport1.isnull().sum().sum()
print(f"Total missing values in Airport1: {total_missing}")

# Count the number of missing values for each column
missing_values_per_column = Airport1.isnull().sum()
print("\nMissing values per column in Airport1:")
print(missing_values_per_column)

# Get a boolean DataFrame indicating the location of missing values
missing_value_locations = Airport1.isnull()
# Out:
# Total missing values in Airport1: 157463
#
# Missing values per column in Airport1:
# date                              0
# idstazione                        0
# lon                               0
# lat                               0
# altezza                           0
# pressure                         29
# three_hour_pressure_change      216
# char_pressure_tendency         2818
# wind_direction                   40
# wind_speed                       40
# relative_humidity             69191
# visibility                       21
# present_weather                  35
# past_weather1                    40
# past_weather2                    42
# cloud_cover                      64
# height_of_base_of_cloud       17669
# cloud_type                        0
# drybulb                       33632
# dewpoint                      33626
# dtype: int64

# %% [markdown]
# Finding the missing values in Airport 2

# %%
# Count the total number of missing values in Airport2
total_missing = Airport2.isnull().sum().sum()
print(f"Total missing values in Airport2: {total_missing}")

# Count the number of missing values for each column
missing_values_per_column = Airport2.isnull().sum()
print("\nMissing values per column in Airport2:")
print(missing_values_per_column)

# Get a boolean DataFrame indicating the location of missing values
missing_value_locations = Airport2.isnull()
# Out:
# Total missing values in Airport2: 410225
#
# Missing values per column in Airport2:
# date                               0
# idstazione                         0
# lon                                0
# lat                                0
# altezza                            0
# pressure                         162
# three_hour_pressure_change       343
# char_pressure_tendency          3166
# wind_direction                    63
# wind_speed                        64
# relative_humidity             175664
# visibility                        23
# present_weather                  115
# past_weather1                    124
# past_weather2                    119
# cloud_cover                       57
# height_of_base_of_cloud        36592
# cloud_type                         0
# drybulb                        96866
# dewpoint                       96867
# dtype: int64

# %% [markdown]
# Finding the missing values in Airport 3

# %%
# Count the total number of missing values in Airport3
total_missing = Airport3.isnull().sum().sum()
print(f"Total missing values in Airport2: {total_missing}")

# Count the number of missing values for each column
missing_values_per_column = Airport3.isnull().sum()
print("\nMissing values per column in Airport3:")
print(missing_values_per_column)

# Get a boolean DataFrame indicating the location of missing values
missing_value_locations = Airport3.isnull()
# Out:
# Total missing values in Airport2: 428951
#
# Missing values per column in Airport3:
# date                               0
# idstazione                         0
# lon                                0
# lat                                0
# altezza                            0
# pressure                          94
# three_hour_pressure_change       250
# char_pressure_tendency          3095
# wind_direction                    63
# wind_speed                        63
# relative_humidity             174112
# visibility                        41
# present_weather                  177
# past_weather1                    185
# past_weather2                    187
# cloud_cover                     1563
# height_of_base_of_cloud        55206
# cloud_type                         0
# drybulb                        96957
# dewpoint                       96958
# dtype: int64

# %% [markdown]
# Finding the missing values of Airport 1 in Percentage

# %%
# Count the number of missing values for each column
missing_values_count = Airport1.isnull().sum()

# Calculate the percentage of missing values for each column
total_rows = len(Airport1)
missing_values_percentage = (missing_values_count / total_rows) * 100

# Create a DataFrame to display the results
missing_values_df = pd.DataFrame({
    'Column': missing_values_count.index,
    'Missing Values': missing_values_count.values,
    'Percentage': missing_values_percentage.values
})

# Sort the DataFrame by the 'Percentage' column in descending order
missing_values_df = missing_values_df.sort_values(by='Percentage', ascending=False)

# Display the results
print(missing_values_df)
# Out:
#                         Column  Missing Values  Percentage
# 10           relative_humidity           69191  100.000000
# 18                     drybulb           33632   48.607478
# 19                    dewpoint           33626   48.598806
# 16     height_of_base_of_cloud           17669   25.536558
# 7       char_pressure_tendency            2818    4.072784
# 6   three_hour_pressure_change             216    0.312179
# 15                 cloud_cover              64    0.092498
# 14               past_weather2              42    0.060702
# 8               wind_direction              40    0.057811
# 9                   wind_speed              40    0.057811
# 13               past_weather1              40    0.057811
# 12             present_weather              35    0.050585
# 5                     pressure              29    0.041913
# 11                  visibility              21    0.030351
# 2                          lon               0    0.000000
# 17                  cloud_type               0    0.000000
# 3                          lat               0    0.000000
# 4                      altezza               0    0.000000
# 1                   idstazione               0    0.000000
# 0                         date               0    0.000000

# %% [markdown]
# Finding the missing values of Airport 2 in Percentage

# %%
# Count the number of missing values for each column
missing_values_count = Airport2.isnull().sum()

# Calculate the percentage of missing values for each column
total_rows = len(Airport2)
missing_values_percentage = (missing_values_count / total_rows) * 100

# Create a DataFrame to display the results
missing_values_df = pd.DataFrame({
    'Column': missing_values_count.index,
    'Missing Values': missing_values_count.values,
    'Percentage': missing_values_percentage.values
})

# Sort the DataFrame by the 'Percentage' column in descending order
missing_values_df = missing_values_df.sort_values(by='Percentage', ascending=False)

# Display the results
print(missing_values_df)
# Out:
#                         Column  Missing Values  Percentage
# 10           relative_humidity          175664   99.998861
# 19                    dewpoint           96867   55.142714
# 18                     drybulb           96866   55.142145
# 16     height_of_base_of_cloud           36592   20.830440
# 7       char_pressure_tendency            3166    1.802284
# 6   three_hour_pressure_change             343    0.195257
# 5                     pressure             162    0.092220
# 13               past_weather1             124    0.070589
# 14               past_weather2             119    0.067742
# 12             present_weather             115    0.065465
# 9                   wind_speed              64    0.036433
# 8               wind_direction              63    0.035864
# 15                 cloud_cover              57    0.032448
# 11                  visibility              23    0.013093
# 17                  cloud_type               0    0.000000
# 2                          lon               0    0.000000
# 3                          lat               0    0.000000
# 1                   idstazione               0    0.000000
# 4                      altezza               0    0.000000
# 0                         date               0    0.000000

# %% [markdown]
# Finding the missing values of Airport 3 in Percentage

# %%
# Count the number of missing values for each column
missing_values_count = Airport3.isnull().sum()

# Calculate the percentage of missing values for each column
total_rows = len(Airport3)
missing_values_percentage = (missing_values_count / total_rows) * 100

# Create a DataFrame to display the results
missing_values_df = pd.DataFrame({
    'Column': missing_values_count.index,
    'Missing Values': missing_values_count.values,
    'Percentage': missing_values_percentage.values
})

# Sort the DataFrame by the 'Percentage' column in descending order
missing_values_df = missing_values_df.sort_values(by='Percentage', ascending=False)

# Display the results
print(missing_values_df)
# Out:
#                         Column  Missing Values  Percentage
# 10           relative_humidity          174112  100.000000
# 19                    dewpoint           96958   55.687144
# 18                     drybulb           96957   55.686570
# 16     height_of_base_of_cloud           55206   31.707177
# 7       char_pressure_tendency            3095    1.777591
# 15                 cloud_cover            1563    0.897698
# 6   three_hour_pressure_change             250    0.143586
# 14               past_weather2             187    0.107402
# 13               past_weather1             185    0.106253
# 12             present_weather             177    0.101659
# 5                     pressure              94    0.053988
# 8               wind_direction              63    0.036184
# 9                   wind_speed              63    0.036184
# 11                  visibility              41    0.023548
# 17                  cloud_type               0    0.000000
# 2                          lon               0    0.000000
# 3                          lat               0    0.000000
# 1                   idstazione               0    0.000000
# 4                      altezza               0    0.000000
# 0                         date               0    0.000000

# %% [markdown]
# Summery of the Airport 1

# %%
# Get summary statistics
summary = Airport1.describe()
print(summary)
# Out:
#        idstazione           lon           lat  altezza       pressure  \
# count     69191.0  69191.000000  69191.000000  69191.0   69162.000000
# mean      16253.0     14.071717     41.051717     10.0  101446.042914
# std           0.0      0.003772      0.003772      0.0     670.824758
# min       16253.0     14.070000     41.050000     10.0   97900.000000
# 25%       16253.0     14.070000     41.050000     10.0  101090.000000
# 50%       16253.0     14.070000     41.050000     10.0  101450.000000
# 75%       16253.0     14.070000     41.050000     10.0  101820.000000
# max       16253.0     14.080000     41.060000     10.0  103910.000000
#
#        three_hour_pressure_change  char_pressure_tendency  wind_direction  \
# count                68975.000000            66373.000000    69151.000000
# mean                     2.892787                4.280159      145.339764
# std                     95.335549                2.537008      116.998655
# min                   -690.000000                0.000000        0.000000
# 25%                    -50.000000                2.000000       40.000000
# 50%                      0.000000                4.000000      110.000000
# 75%                     50.000000                7.000000      250.000000
# max                   1030.000000                8.000000      360.000000
#
#          wind_speed  relative_humidity    visibility  present_weather  \
# count  69151.000000                0.0  69170.000000     69156.000000
# mean       5.797078                NaN  13989.064623         8.318599
# std        4.060721                NaN   7264.649722        16.410110
# min        0.000000                NaN     50.000000         1.000000
# 25%        3.887600                NaN  10000.000000         2.000000
# 50%        5.831400                NaN  14000.000000         2.000000
# 75%        7.775200                NaN  20000.000000        10.000000
# max      103.021000                NaN  75000.000000        99.000000
#
#        past_weather1  past_weather2   cloud_cover  height_of_base_of_cloud  \
# count   69151.000000   69149.000000  69127.000000             51522.000000
# mean        1.810603       1.278008      3.533540              1711.598152
# std         2.108923       1.139510      2.808543              2095.770095
# min         0.000000       0.000000      0.000000                30.000000
# 25%         1.000000       1.000000      1.000000               800.000000
# 50%         1.000000       1.000000      3.000000               800.000000
# 75%         1.000000       1.000000      6.000000              1750.000000
# max         9.000000       9.000000      8.000000              8000.000000
#
#          cloud_type       drybulb      dewpoint
# count  69191.000000  35559.000000  35565.000000
# mean      40.199376     16.610924     11.704199
# std       12.829999      7.614871      7.198172
# min       30.000000     -4.949990    -29.950000
# 25%       31.000000     11.050000      6.950000
# 50%       34.000000     16.050000     11.850000
# 75%       39.000000     22.050000     17.050000
# max       62.000000     39.450000     32.350000

# %% [markdown]
# Summery of the Airport 2

# %%
# Get summary statistics
summary = Airport2.describe()
print(summary)
# Out:
#        idstazione            lon            lat   altezza       pressure  \
# count    175666.0  175666.000000  175666.000000  175666.0  175504.000000
# mean      16429.0      12.499319      37.919319       9.0  101489.719437
# std           0.0       0.002520       0.002520       0.0     596.142359
# min       16429.0      12.490000      37.910000       9.0   90660.000000
# 25%       16429.0      12.500000      37.920000       9.0  101170.000000
# 50%       16429.0      12.500000      37.920000       9.0  101490.000000
# 75%       16429.0      12.500000      37.920000       9.0  101810.000000
# max       16429.0      12.500000      37.920000       9.0  107100.000000
#
#        three_hour_pressure_change  char_pressure_tendency  wind_direction  \
# count               175323.000000           172500.000000   175603.000000
# mean                     2.678599                4.099107      191.033399
# std                     93.044439                2.561327      113.307126
# min                  -1040.000000                0.000000        0.000000
# 25%                    -50.000000                2.000000      120.000000
# 50%                     10.000000                4.000000      170.000000
# 75%                     60.000000                6.000000      300.000000
# max                   1070.000000                8.000000      500.000000
#
#           wind_speed  relative_humidity     visibility  present_weather  \
# count  175602.000000                2.0  175643.000000    175551.000000
# mean        8.011608               63.0   15599.350102         5.980621
# std         5.961997                0.0    4627.216804        14.475209
# min         0.000000               63.0      30.000000         0.000000
# 25%         3.887600               63.0   12000.000000         2.000000
# 50%         7.775200               63.0   15000.000000         2.000000
# 75%        11.662800               63.0   20000.000000         2.000000
# max       320.727000               63.0   75000.000000        99.000000
#
#        past_weather1  past_weather2    cloud_cover  height_of_base_of_cloud  \
# count  175542.000000  175547.000000  175609.000000            139074.000000
# mean        1.554716       1.217856       3.463370              1335.546615
# std         1.699310       0.924737       2.592045              1877.726271
# min         0.000000       0.000000       0.000000                30.000000
# 25%         1.000000       1.000000       1.000000               450.000000
# 50%         1.000000       1.000000       3.000000               800.000000
# 75%         1.000000       1.000000       6.000000               800.000000
# max        20.000000      19.000000       8.000000              8000.000000
#
#           cloud_type       drybulb      dewpoint
# count  175666.000000  78800.000000  78799.000000
# mean       39.321047     18.389478     14.205437
# std        11.768341      6.446896      5.715026
# min        17.000000      1.050000    -29.950000
# 25%        32.000000     13.450000     10.050000
# 50%        35.000000     17.850000     13.850000
# 75%        38.000000     23.250000     18.650000
# max        62.000000     60.050000     48.950000

# %% [markdown]
# Summery of the Airport 3

# %%
# Get summary statistics
summary = Airport3.describe()
print(summary)
# Out:
#        idstazione            lon           lat   altezza       pressure  \
# count    174112.0  174112.000000  1.741120e+05  174112.0  174018.000000
# mean      16098.0      12.100687  4.568000e+01      42.0  101099.900413
# std           0.0       0.002529  2.131634e-14       0.0     751.521598
# min       16098.0      12.100000  4.568000e+01      42.0   97050.000000
# 25%       16098.0      12.100000  4.568000e+01      42.0  100670.000000
# 50%       16098.0      12.100000  4.568000e+01      42.0  101100.000000
# 75%       16098.0      12.100000  4.568000e+01      42.0  101560.000000
# max       16098.0      12.110000  4.568000e+01      42.0  107030.000000
#
#        three_hour_pressure_change  char_pressure_tendency  wind_direction  \
# count               173862.000000           171017.000000   174049.000000
# mean                     1.822307                4.302338      107.155652
# std                    107.115723                2.661734      112.976549
# min                  -3890.000000                0.000000        0.000000
# 25%                    -60.000000                2.000000       10.000000
# 50%                      0.000000                4.000000       60.000000
# 75%                     60.000000                7.000000      180.000000
# max                   1000.000000                8.000000      500.000000
#
#           wind_speed  relative_humidity     visibility  present_weather  \
# count  174049.000000                0.0  174071.000000    173935.000000
# mean        3.966715                NaN   12942.608648        11.214845
# std         3.324492                NaN    9105.024618        18.725528
# min         0.000000                NaN      30.000000         0.000000
# 25%         1.943800                NaN    6000.000000         2.000000
# 50%         3.887600                NaN   10000.000000         2.000000
# 75%         5.831400                NaN   16000.000000        10.000000
# max       157.448000                NaN   75000.000000        99.000000
#
#        past_weather1  past_weather2    cloud_cover  height_of_base_of_cloud  \
# count  173927.000000  173925.000000  172549.000000            118906.000000
# mean        1.891794       1.480149       3.795038              2255.493247
# std         2.067999       1.407090       3.072375              2404.431196
# min         0.000000       0.000000       0.000000                30.000000
# 25%         1.000000       1.000000       0.000000               800.000000
# 50%         1.000000       1.000000       4.000000              1250.000000
# 75%         2.000000       2.000000       7.000000              3500.000000
# max         9.000000       9.000000       8.000000              8000.000000
#
#           cloud_type       drybulb      dewpoint
# count  174112.000000  77155.000000  77154.000000
# mean       41.707016     14.417406      9.626815
# std        13.886508      8.463814      7.441474
# min        30.000000     -8.750000    -29.950000
# 25%        30.000000      7.850000      4.050000
# 50%        35.000000     14.050000      9.850000
# 75%        62.000000     20.850000     15.650000
# max        62.000000     55.050000     29.650000

# %% [markdown]
# Checking common collum name in the data set

# %%
import pandas as pd


# Get the column names of each dataset
cols1 = set(Airport1.columns)
cols2 = set(Airport2.columns)
cols3 = set(Airport3.columns)

# Find the common column names
common_cols = cols1.intersection(cols2, cols3)

# Print the common column names
print("Common column names in all three datasets:")
for col in common_cols:
    print(col)
# Out:
# Common column names in all three datasets:
# visibility
# date
# lon
# dewpoint
# char_pressure_tendency
# lat
# height_of_base_of_cloud
# pressure
# wind_direction
# past_weather1
# past_weather2
# idstazione
# cloud_cover
# relative_humidity
# three_hour_pressure_change
# wind_speed
# cloud_type
# present_weather
# altezza
# drybulb

# %% [markdown]
# Checking there is uniqe collum name in the dataset

# %%
# Find the common column names
common_cols = cols1.intersection(cols2, cols3)

# Find the unique column names in each dataset
unique_cols1 = cols1 - common_cols
unique_cols2 = cols2 - common_cols
unique_cols3 = cols3 - common_cols

# Print the common column names
print("Common column names in all three datasets:")
for col in common_cols:
    print(col)

# Print the unique column names in each dataset
print("\nUnique column names in Airport1:")
for col in unique_cols1:
    print(col)

print("\nUnique column names in Airport2:")
for col in unique_cols2:
    print(col)

print("\nUnique column names in Airport3:")
for col in unique_cols3:
    print(col)
# Out:
# Common column names in all three datasets:
# visibility
# date
# lon
# dewpoint
# char_pressure_tendency
# lat
# height_of_base_of_cloud
# pressure
# wind_direction
# past_weather1
# past_weather2
# idstazione
# cloud_cover
# relative_humidity
# three_hour_pressure_change
# wind_speed
# cloud_type
# present_weather
# altezza
# drybulb
#
# Unique column names in Airport1:
#
# Unique column names in Airport2:
#
# Unique column names in Airport3:

# %% [markdown]
# Box Plot for outlayers

# %%
# Load the dataset
Airport1 = pd.read_excel('/content/Grazzanise airport.xlsx', parse_dates=['date'])

# Convert the 'dewpoint' column to datetime
Airport1['dewpoint'] = pd.to_datetime(Airport1['dewpoint'])

# Check the range of dates in the 'relative_humidity' column
print("Minimum date in 'dewpoint' column:", Airport1['dewpoint'].min())
print("Maximum date in 'dewpoint' column:", Airport1['dewpoint'].max())
# Out:
# <ipython-input-20-81922e3c8d95>:2: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   Airport1 = pd.read_excel('/content/Grazzanise airport.xlsx', parse_dates=['date'])
# Minimum date in 'dewpoint' column: 1969-12-31 23:59:59.999999971
# Maximum date in 'dewpoint' column: 1970-01-01 00:00:00.000000032

# %%
import pandas as pd

# Load the dataset
Airport1 = pd.read_excel('/content/Grazzanise airport.xlsx', parse_dates=['date'])

# Convert the 'dewpoint' column to datetime
Airport1['dewpoint'] = pd.to_datetime(Airport1['dewpoint'])

# Sort the 'dewpoint' column by date
Airport1 = Airport1.sort_values(by='dewpoint')

# Get the earliest date in the 'relative_humidity' column
earliest_date = Airport1['dewpoint'].dropna().min()

print(f"Data is available in the 'dewpoint' column from: {earliest_date}")
# Out:
# <ipython-input-21-3d78472454b7>:4: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   Airport1 = pd.read_excel('/content/Grazzanise airport.xlsx', parse_dates=['date'])
# Data is available in the 'dewpoint' column from: 1969-12-31 23:59:59.999999971

# %% [markdown]
# Removed the Relative_humiditu from the Airport1

# %%
def remove_column_from_airport1(column_name):
    if column_name in Airport1.columns:
        Airport1.drop(column_name, axis=1, inplace=True)
        print(f"Column '{column_name}' removed successfully from Airport1.")
    else:
        print(f"Column '{column_name}' not found in Airport1.")

# Example usage:
# Suppose you want to remove the column named 'relative_humidity' from 'Airport1'
remove_column_from_airport1('relative_humidity')
# Out:
# Column 'relative_humidity' removed successfully from Airport1.

# %%
Airport1
# Out:
#                      date  idstazione    lon    lat  altezza  pressure  \
# 65363 2023-04-27 09:00:00       16253  14.08  41.06       10  101660.0
# 68124 2023-09-11 08:00:00       16253  14.08  41.06       10  101520.0
# 50952 2020-03-28 03:00:00       16253  14.07  41.05       10  101130.0
# 64042 2023-02-20 02:00:00       16253  14.08  41.06       10  102300.0
# 48834 2019-02-23 06:00:00       16253  14.07  41.05       10  101940.0
# ...                   ...         ...    ...    ...      ...       ...
# 33621 2013-08-31 15:00:00       16253  14.07  41.05       10  101470.0
# 33622 2013-08-31 18:00:00       16253  14.07  41.05       10  101420.0
# 33623 2013-08-31 21:00:00       16253  14.07  41.05       10  101610.0
# 65330 2023-04-26 00:00:00       16253  14.08  41.06       10       NaN
# 65952 2023-05-23 00:00:00       16253  14.08  41.06       10       NaN
#
#        three_hour_pressure_change  char_pressure_tendency  wind_direction  \
# 65363                         NaN                     NaN           360.0
# 68124                        90.0                     2.0           360.0
# 50952                       -50.0                     8.0            10.0
# 64042                         0.0                     4.0           300.0
# 48834                       160.0                     3.0            20.0
# ...                           ...                     ...             ...
# 33621                      -100.0                     6.0           290.0
# 33622                       -50.0                     5.0           310.0
# 33623                       190.0                     1.0            60.0
# 65330                         NaN                     NaN           130.0
# 65952                         NaN                     NaN            20.0
#
#        wind_speed  visibility  present_weather  past_weather1  past_weather2  \
# 65363      1.9438        50.0              2.0            1.0            1.0
# 68124      9.7190     16000.0              2.0            1.0            1.0
# 50952      5.8314     12000.0             60.0            6.0            6.0
# 64042      3.8876      8000.0             10.0            2.0            2.0
# 48834     21.3818     25000.0              2.0            1.0            1.0
# ...           ...         ...              ...            ...            ...
# 33621      7.7752     20000.0              2.0            1.0            1.0
# 33622      3.8876     20000.0              2.0            1.0            1.0
# 33623      3.8876     20000.0              2.0            1.0            1.0
# 65330     29.1570      7000.0              NaN            NaN            NaN
# 65952      1.9438     10000.0              2.0            1.0            1.0
#
#        cloud_cover  height_of_base_of_cloud  cloud_type  drybulb  \
# 65363          1.0                   8000.0          30    18.85
# 68124          0.0                      NaN          62    25.65
# 50952          7.0                    800.0          32    10.05
# 64042          5.0                    800.0          35     9.05
# 48834          1.0                    800.0          32     6.05
# ...            ...                      ...         ...      ...
# 33621          2.0                    800.0          31      NaN
# 33622          2.0                   8000.0          30      NaN
# 33623          2.0                   8000.0          30      NaN
# 65330          0.0                      NaN          62      NaN
# 65952          0.0                      NaN          62    15.45
#
#                            dewpoint
# 65363 1969-12-31 23:59:59.999999971
# 68124 1969-12-31 23:59:59.999999971
# 50952 1969-12-31 23:59:59.999999971
# 64042 1969-12-31 23:59:59.999999971
# 48834 1969-12-31 23:59:59.999999980
# ...                             ...
# 33621                           NaT
# 33622                           NaT
# 33623                           NaT
# 65330                           NaT
# 65952                           NaT
#
# [69191 rows x 19 columns]

# %%
def remove_column_from_airport2(column_name):
    if column_name in Airport2.columns:
        Airport2.drop(column_name, axis=1, inplace=True)
        print(f"Column '{column_name}' removed successfully from Airport2.")
    else:
        print(f"Column '{column_name}' not found in Airport2.")

# Example usage:
# Suppose you want to remove the column named 'relative_humidity' from 'Airport2'
remove_column_from_airport2('relative_humidity')
# Out:
# Column 'relative_humidity' removed successfully from Airport2.

# %%
def remove_column_from_airport3(column_name):
    if column_name in Airport3.columns:
        Airport3.drop(column_name, axis=1, inplace=True)
        print(f"Column '{column_name}' removed successfully from Airport3.")
    else:
        print(f"Column '{column_name}' not found in Airport3.")

# Example usage:
# Suppose you want to remove the column named 'relative_humidity' from 'Airport3'
remove_column_from_airport3('relative_humidity')
# Out:
# Column 'relative_humidity' removed successfully from Airport3.

# %%
Airport3
# Out:
#                     date  idstazione    lon    lat  altezza  pressure  \
# 0       01/01/1996 00:00       16098  12.10  45.68       42   99090.0
# 1       01/01/1996 03:00       16098  12.10  45.68       42   99210.0
# 2       01/01/1996 06:00       16098  12.10  45.68       42   99330.0
# 3       01/01/1996 09:00       16098  12.10  45.68       42       NaN
# 4       01/01/1996 12:00       16098  12.10  45.68       42   99640.0
# ...                  ...         ...    ...    ...      ...       ...
# 174107  18/11/2023 19:00       16098  12.11  45.68       42  101760.0
# 174108  18/11/2023 20:00       16098  12.11  45.68       42  101830.0
# 174109  18/11/2023 21:00       16098  12.11  45.68       42  101800.0
# 174110  18/11/2023 22:00       16098  12.11  45.68       42  101800.0
# 174111  18/11/2023 23:00       16098  12.11  45.68       42  101770.0
#
#         three_hour_pressure_change  char_pressure_tendency  wind_direction  \
# 0                            100.0                     2.0            10.0
# 1                            120.0                     2.0             0.0
# 2                            120.0                     2.0            20.0
# 3                              NaN                     NaN             0.0
# 4                             20.0                     1.0            40.0
# ...                            ...                     ...             ...
# 174107                        10.0                     1.0            10.0
# 174108                        60.0                     2.0           360.0
# 174109                       100.0                     2.0            80.0
# 174110                        40.0                     3.0           120.0
# 174111                       -70.0                     8.0            10.0
#
#         wind_speed  visibility  present_weather  past_weather1  past_weather2  \
# 0           5.8314      4000.0             10.0            6.0            5.0
# 1           1.9438      3000.0             50.0            5.0            2.0
# 2           1.9438      2500.0             60.0            6.0            5.0
# 3           1.9438      2500.0              NaN            NaN            NaN
# 4           5.8314      8000.0             10.0            6.0            2.0
# ...            ...         ...              ...            ...            ...
# 174107      5.8314     15000.0              2.0            1.0            1.0
# 174108      1.9438     15000.0              2.0            1.0            1.0
# 174109      3.8876     15000.0              2.0            1.0            1.0
# 174110      1.9438     15000.0              2.0            1.0            1.0
# 174111      1.9438     15000.0              2.0            1.0            1.0
#
#         cloud_cover  height_of_base_of_cloud  cloud_type  drybulb  dewpoint
# 0               8.0                    800.0          37      NaN       NaN
# 1               8.0                    450.0          37      NaN       NaN
# 2               8.0                    450.0          37      NaN       NaN
# 3               8.0                      NaN          62      NaN       NaN
# 4               8.0                    800.0          35      NaN       NaN
# ...             ...                      ...         ...      ...       ...
# 174107          1.0                   2250.0          30     5.65      3.05
# 174108          0.0                      NaN          62     4.85      2.55
# 174109          1.0                   8000.0          30     4.45      2.15
# 174110          0.0                      NaN          62     3.65      2.05
# 174111          0.0                      NaN          62     3.05      1.55
#
# [174112 rows x 19 columns]

# %% [markdown]
# Checking the value count of each

# %%
Airport1.height_of_base_of_cloud.value_counts()
# Out:
# height_of_base_of_cloud
# 800.0     25109
# 450.0      6779
# 2250.0     5155
# 8000.0     4603
# 1250.0     4585
# 3500.0     2149
# 1750.0     1814
# 150.0       602
# 250.0       296
# 80.0        246
# 30.0        181
# 2600.0        3
# Name: count, dtype: int64

# %%
mod_cloud = Airport1['height_of_base_of_cloud'].mode()
mod_of_clouds = mod_cloud.fillna(mod_cloud[0],inplace=True)
mod_of_clouds

# %%
Airport1
# Out:
#                      date  idstazione    lon    lat  altezza  pressure  \
# 65363 2023-04-27 09:00:00       16253  14.08  41.06       10  101660.0
# 68124 2023-09-11 08:00:00       16253  14.08  41.06       10  101520.0
# 50952 2020-03-28 03:00:00       16253  14.07  41.05       10  101130.0
# 64042 2023-02-20 02:00:00       16253  14.08  41.06       10  102300.0
# 48834 2019-02-23 06:00:00       16253  14.07  41.05       10  101940.0
# ...                   ...         ...    ...    ...      ...       ...
# 33621 2013-08-31 15:00:00       16253  14.07  41.05       10  101470.0
# 33622 2013-08-31 18:00:00       16253  14.07  41.05       10  101420.0
# 33623 2013-08-31 21:00:00       16253  14.07  41.05       10  101610.0
# 65330 2023-04-26 00:00:00       16253  14.08  41.06       10       NaN
# 65952 2023-05-23 00:00:00       16253  14.08  41.06       10       NaN
#
#        three_hour_pressure_change  char_pressure_tendency  wind_direction  \
# 65363                         NaN                     NaN           360.0
# 68124                        90.0                     2.0           360.0
# 50952                       -50.0                     8.0            10.0
# 64042                         0.0                     4.0           300.0
# 48834                       160.0                     3.0            20.0
# ...                           ...                     ...             ...
# 33621                      -100.0                     6.0           290.0
# 33622                       -50.0                     5.0           310.0
# 33623                       190.0                     1.0            60.0
# 65330                         NaN                     NaN           130.0
# 65952                         NaN                     NaN            20.0
#
#        wind_speed  visibility  present_weather  past_weather1  past_weather2  \
# 65363      1.9438        50.0              2.0            1.0            1.0
# 68124      9.7190     16000.0              2.0            1.0            1.0
# 50952      5.8314     12000.0             60.0            6.0            6.0
# 64042      3.8876      8000.0             10.0            2.0            2.0
# 48834     21.3818     25000.0              2.0            1.0            1.0
# ...           ...         ...              ...            ...            ...
# 33621      7.7752     20000.0              2.0            1.0            1.0
# 33622      3.8876     20000.0              2.0            1.0            1.0
# 33623      3.8876     20000.0              2.0            1.0            1.0
# 65330     29.1570      7000.0              NaN            NaN            NaN
# 65952      1.9438     10000.0              2.0            1.0            1.0
#
#        cloud_cover  height_of_base_of_cloud  cloud_type  drybulb  \
# 65363          1.0                   8000.0          30    18.85
# 68124          0.0                      NaN          62    25.65
# 50952          7.0                    800.0          32    10.05
# 64042          5.0                    800.0          35     9.05
# 48834          1.0                    800.0          32     6.05
# ...            ...                      ...         ...      ...
# 33621          2.0                    800.0          31      NaN
# 33622          2.0                   8000.0          30      NaN
# 33623          2.0                   8000.0          30      NaN
# 65330          0.0                      NaN          62      NaN
# 65952          0.0                      NaN          62    15.45
#
#                            dewpoint
# 65363 1969-12-31 23:59:59.999999971
# 68124 1969-12-31 23:59:59.999999971
# 50952 1969-12-31 23:59:59.999999971
# 64042 1969-12-31 23:59:59.999999971
# 48834 1969-12-31 23:59:59.999999980
# ...                             ...
# 33621                           NaT
# 33622                           NaT
# 33623                           NaT
# 65330                           NaT
# 65952                           NaT
#
# [69191 rows x 19 columns]

# %%
mod_cloud = Airport1['height_of_base_of_cloud'].isnull().sum()
# mod_of_clouds = mod_cloud.fillna(mod_cloud[0],inplace=True)

# %%
mod_cloud
# Out:
# 17669

# %%
mod_cloud = Airport1['height_of_base_of_cloud'].mode()
mod_of_clouds = mod_cloud.fillna(mod_cloud[0],inplace=True)

# %% [markdown]
# Fill the null values with mode

# %%
Airport1['height_of_base_of_cloud'].fillna(800, inplace = True)
Airport2['height_of_base_of_cloud'].fillna(800, inplace = True)
Airport3['height_of_base_of_cloud'].fillna(800, inplace = True)

# %%
Airport1['height_of_base_of_cloud'].isnull().sum()
Airport2['height_of_base_of_cloud'].isnull().sum()
Airport3['height_of_base_of_cloud'].isnull().sum()
# Out:
# 0

# %%
Airport1
# Out:
#                      date  idstazione    lon    lat  altezza  pressure  \
# 65363 2023-04-27 09:00:00       16253  14.08  41.06       10  101660.0
# 68124 2023-09-11 08:00:00       16253  14.08  41.06       10  101520.0
# 50952 2020-03-28 03:00:00       16253  14.07  41.05       10  101130.0
# 64042 2023-02-20 02:00:00       16253  14.08  41.06       10  102300.0
# 48834 2019-02-23 06:00:00       16253  14.07  41.05       10  101940.0
# ...                   ...         ...    ...    ...      ...       ...
# 33621 2013-08-31 15:00:00       16253  14.07  41.05       10  101470.0
# 33622 2013-08-31 18:00:00       16253  14.07  41.05       10  101420.0
# 33623 2013-08-31 21:00:00       16253  14.07  41.05       10  101610.0
# 65330 2023-04-26 00:00:00       16253  14.08  41.06       10       NaN
# 65952 2023-05-23 00:00:00       16253  14.08  41.06       10       NaN
#
#        three_hour_pressure_change  char_pressure_tendency  wind_direction  \
# 65363                         NaN                     NaN           360.0
# 68124                        90.0                     2.0           360.0
# 50952                       -50.0                     8.0            10.0
# 64042                         0.0                     4.0           300.0
# 48834                       160.0                     3.0            20.0
# ...                           ...                     ...             ...
# 33621                      -100.0                     6.0           290.0
# 33622                       -50.0                     5.0           310.0
# 33623                       190.0                     1.0            60.0
# 65330                         NaN                     NaN           130.0
# 65952                         NaN                     NaN            20.0
#
#        wind_speed  visibility  present_weather  past_weather1  past_weather2  \
# 65363      1.9438        50.0              2.0            1.0            1.0
# 68124      9.7190     16000.0              2.0            1.0            1.0
# 50952      5.8314     12000.0             60.0            6.0            6.0
# 64042      3.8876      8000.0             10.0            2.0            2.0
# 48834     21.3818     25000.0              2.0            1.0            1.0
# ...           ...         ...              ...            ...            ...
# 33621      7.7752     20000.0              2.0            1.0            1.0
# 33622      3.8876     20000.0              2.0            1.0            1.0
# 33623      3.8876     20000.0              2.0            1.0            1.0
# 65330     29.1570      7000.0              NaN            NaN            NaN
# 65952      1.9438     10000.0              2.0            1.0            1.0
#
#        cloud_cover  height_of_base_of_cloud  cloud_type  drybulb  \
# 65363          1.0                   8000.0          30    18.85
# 68124          0.0                    800.0          62    25.65
# 50952          7.0                    800.0          32    10.05
# 64042          5.0                    800.0          35     9.05
# 48834          1.0                    800.0          32     6.05
# ...            ...                      ...         ...      ...
# 33621          2.0                    800.0          31      NaN
# 33622          2.0                   8000.0          30      NaN
# 33623          2.0                   8000.0          30      NaN
# 65330          0.0                    800.0          62      NaN
# 65952          0.0                    800.0          62    15.45
#
#                            dewpoint
# 65363 1969-12-31 23:59:59.999999971
# 68124 1969-12-31 23:59:59.999999971
# 50952 1969-12-31 23:59:59.999999971
# 64042 1969-12-31 23:59:59.999999971
# 48834 1969-12-31 23:59:59.999999980
# ...                             ...
# 33621                           NaT
# 33622                           NaT
# 33623                           NaT
# 65330                           NaT
# 65952                           NaT
#
# [69191 rows x 19 columns]

# %%
Airport1.dropna(subset=['dewpoint'],inplace = True)
Airport1.dropna(subset=['drybulb'],inplace = True)

# %%
Airport1.drybulb.isna().sum()
Airport1.dewpoint.isna().sum()
Airport1.isna().sum()
# Out:
# date                            0
# idstazione                      0
# lon                             0
# lat                             0
# altezza                         0
# pressure                        2
# three_hour_pressure_change    158
# char_pressure_tendency        158
# wind_direction                 12
# wind_speed                     12
# visibility                      0
# present_weather                 0
# past_weather1                   1
# past_weather2                   2
# cloud_cover                    13
# height_of_base_of_cloud         0
# cloud_type                      0
# drybulb                         0
# dewpoint                        0
# dtype: int64

# %%
Airport2.dropna(subset=['dewpoint'],inplace = True)
Airport2.dropna(subset=['drybulb'],inplace = True)

# %%
Airport3.dropna(subset=['dewpoint'],inplace = True)
Airport3.dropna(subset=['drybulb'],inplace = True)

# %%
Airport1.isna().sum()
# Out:
# date                            0
# idstazione                      0
# lon                             0
# lat                             0
# altezza                         0
# pressure                        2
# three_hour_pressure_change    158
# char_pressure_tendency        158
# wind_direction                 12
# wind_speed                     12
# visibility                      0
# present_weather                 0
# past_weather1                   1
# past_weather2                   2
# cloud_cover                    13
# height_of_base_of_cloud         0
# cloud_type                      0
# drybulb                         0
# dewpoint                        0
# dtype: int64

# %%
Airport2.isna().sum()
# Out:
# date                           0
# idstazione                     0
# lon                            0
# lat                            0
# altezza                        0
# pressure                       0
# three_hour_pressure_change    98
# char_pressure_tendency        98
# wind_direction                 1
# wind_speed                     1
# visibility                     0
# present_weather                0
# past_weather1                  2
# past_weather2                  0
# cloud_cover                    2
# height_of_base_of_cloud        0
# cloud_type                     0
# drybulb                        0
# dewpoint                       0
# dtype: int64

# %%
Airport3.isna().sum()
# Out:
# date                            0
# idstazione                      0
# lon                             0
# lat                             0
# altezza                         0
# pressure                        2
# three_hour_pressure_change    104
# char_pressure_tendency        104
# wind_direction                  0
# wind_speed                      0
# visibility                      0
# present_weather                 3
# past_weather1                   4
# past_weather2                   6
# cloud_cover                   669
# height_of_base_of_cloud         0
# cloud_type                      0
# drybulb                         0
# dewpoint                        0
# dtype: int64

# %%
Airport1.isna().sum()
# Out:
# date                            0
# idstazione                      0
# lon                             0
# lat                             0
# altezza                         0
# pressure                        2
# three_hour_pressure_change    158
# char_pressure_tendency        158
# wind_direction                 12
# wind_speed                     12
# visibility                      0
# present_weather                 0
# past_weather1                   1
# past_weather2                   2
# cloud_cover                    13
# height_of_base_of_cloud         0
# cloud_type                      0
# drybulb                         0
# dewpoint                        0
# dtype: int64

# %%
len(Airport1)
# Out:
# 35558

# %%
len(Airport2)
# Out:
# 78798

# %%
len(Airport3)
# Out:
# 77151

# %%
# Check for missing values
print("Missing values in the dataset:")
print(Airport1.isnull().sum())

# Identify and visualize potential outliers
for column in Airport1.select_dtypes(include=['float64', 'int64']).columns:
    # Create a box plot for the column
    plt.figure(figsize=(10, 6))
    sns.boxplot(data=Airport1, x=column)
    plt.title(f"Box Plot for {column}")
    plt.show()

    # Identify outliers using the interquartile range (IQR) method
    q1 = Airport1[column].quantile(0.25)
    q3 = Airport1[column].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    outliers = Airport1[(Airport1[column] < lower_bound) | (Airport1[column] > upper_bound)]

    if not outliers.empty:
        print(f"Outliers in {column}:")
        print(outliers)
    else:
        print(f"No outliers detected in {column}")
# Out:
# Missing values in the dataset:
# date                            0
# idstazione                      0
# lon                             0
# lat                             0
# altezza                         0
# pressure                        2
# three_hour_pressure_change    158
# char_pressure_tendency        158
# wind_direction                 12
# wind_speed                     12
# visibility                      0
# present_weather                 0
# past_weather1                   1
# past_weather2                   2
# cloud_cover                    13
# height_of_base_of_cloud         0
# cloud_type                      0
# drybulb                         0
# dewpoint                        0
# dtype: int64
# No outliers detected in idstazione
# No outliers detected in lon
# No outliers detected in lat
# No outliers detected in altezza
# Outliers in pressure:
#                      date  idstazione    lon    lat  altezza  pressure  \
# 63839 2023-02-11 13:00:00       16253  14.08  41.06       10  103200.0
# 63840 2023-02-11 14:00:00       16253  14.08  41.06       10  103170.0
# 63838 2023-02-11 12:00:00       16253  14.08  41.06       10  103280.0
# 53167 2021-02-15 09:00:00       16253  14.07  41.05       10  103460.0
# 53166 2021-02-15 06:00:00       16253  14.07  41.05       10  103210.0
# ...                   ...         ...    ...    ...      ...       ...
# 44855 2017-09-11 15:00:00       16253  14.07  41.05       10   99710.0
# 68930 2023-11-03 01:00:00       16253  14.08  41.06       10   99910.0
# 68931 2023-11-03 02:00:00       16253  14.08  41.06       10   99690.0
# 36524 2014-09-01 15:00:00       16253  14.07  41.05       10   99830.0
# 49907 2019-07-28 09:00:00       16253  14.07  41.05       10   99910.0
#
#        three_hour_pressure_change  char_pressure_tendency  wind_direction  \
# 63839                      -100.0                     8.0           300.0
# 63840                      -130.0                     8.0           240.0
# 63838                       -20.0                     8.0           350.0
# 53167                       250.0                     2.0            20.0
# 53166                        30.0                     2.0           350.0
# ...                           ...                     ...             ...
# 44855                      -100.0                     5.0           330.0
# 68930                      -280.0                     7.0           140.0
# 68931                      -360.0                     7.0           160.0
# 36524                      -170.0                     5.0           350.0
# 49907                       -30.0                     5.0           260.0
#
#        wind_speed  visibility  present_weather  past_weather1  past_weather2  \
# 63839      3.8876     15000.0              2.0            1.0            1.0
# 63840      1.9438     15000.0              2.0            1.0            1.0
# 63838      3.8876     15000.0              2.0            1.0            1.0
# 53167     11.6628     20000.0              2.0            1.0            1.0
# 53166     13.6066     12000.0              2.0            1.0            1.0
# ...           ...         ...              ...            ...            ...
# 44855      3.8876     20000.0              2.0            1.0            1.0
# 68930     13.6066     15000.0              2.0            1.0            1.0
# 68931     15.5504      3000.0             95.0            9.0            6.0
# 36524      9.7190     10000.0              2.0            1.0            1.0
# 49907     15.5504     10000.0              2.0            9.0            6.0
#
#        cloud_cover  height_of_base_of_cloud  cloud_type  drybulb  \
# 63839          0.0                    800.0          62    13.05
# 63840          0.0                    800.0          62    13.05
# 63838          0.0                    800.0          62    12.05
# 53167          2.0                    800.0          31     6.05
# 53166          1.0                   1250.0          32     2.85
# ...            ...                      ...         ...      ...
# 44855          7.0                    800.0          31    21.05
# 68930          7.0                    800.0          32    21.05
# 68931          8.0                    450.0          33    20.05
# 36524          6.0                    800.0          38    25.45
# 49907          6.0                    450.0          38    28.05
#
#                            dewpoint
# 63839 1969-12-31 23:59:59.999999988
# 63840 1969-12-31 23:59:59.999999990
# 63838 1969-12-31 23:59:59.999999990
# 53167 1969-12-31 23:59:59.999999990
# 53166 1969-12-31 23:59:59.999999990
# ...                             ...
# 44855 1970-01-01 00:00:00.000000019
# 68930 1970-01-01 00:00:00.000000019
# 68931 1970-01-01 00:00:00.000000019
# 36524 1970-01-01 00:00:00.000000020
# 49907 1970-01-01 00:00:00.000000022
#
# [1181 rows x 19 columns]
# Outliers in three_hour_pressure_change:
#                      date  idstazione    lon    lat  altezza  pressure  \
# 63681 2023-02-04 23:00:00       16253  14.08  41.06       10  102460.0
# 63679 2023-02-04 21:00:00       16253  14.08  41.06       10  102290.0
# 63680 2023-02-04 22:00:00       16253  14.08  41.06       10  102390.0
# 56346 2022-02-01 16:00:00       16253  14.07  41.05       10  100770.0
# 63695 2023-02-05 13:00:00       16253  14.08  41.06       10  102550.0
# ...                   ...         ...    ...    ...      ...       ...
# 47205 2018-07-05 18:00:00       16253  14.07  41.05       10  101110.0
# 36292 2014-08-03 15:00:00       16253  14.07  41.05       10  101100.0
# 44294 2017-06-28 12:00:00       16253  14.07  41.05       10  100660.0
# 36252 2014-07-29 15:00:00       16253  14.07  41.05       10  100800.0
# 47293 2018-07-16 18:00:00       16253  14.07  41.05       10  101200.0
#
#        three_hour_pressure_change  char_pressure_tendency  wind_direction  \
# 63681                       270.0                     1.0           360.0
# 63679                       320.0                     2.0            20.0
# 63680                       240.0                     2.0            10.0
# 56346                       220.0                     2.0            20.0
# 63695                      -230.0                     7.0           350.0
# ...                           ...                     ...             ...
# 47205                      -210.0                     6.0           260.0
# 36292                      -220.0                     7.0           270.0
# 44294                      -350.0                     7.0           120.0
# 36252                      -230.0                     8.0           240.0
# 47293                      -320.0                     7.0           260.0
#
#        wind_speed  visibility  present_weather  past_weather1  past_weather2  \
# 63681     17.4942     20000.0              2.0            1.0            1.0
# 63679     19.4380     20000.0              2.0            1.0            1.0
# 63680     11.6628     20000.0              2.0            1.0            1.0
# 56346     19.4380     20000.0              2.0            1.0            1.0
# 63695     23.3256     30000.0              2.0            1.0            1.0
# ...           ...         ...              ...            ...            ...
# 47205      1.9438     10000.0              2.0            1.0            1.0
# 36292      9.7190     10000.0              2.0            1.0            1.0
# 44294      5.8314     10000.0              2.0            1.0            1.0
# 36252      7.7752     10000.0              2.0            1.0            1.0
# 47293      3.8876     15000.0              3.0            6.0            2.0
#
#        cloud_cover  height_of_base_of_cloud  cloud_type  drybulb  \
# 63681          0.0                    800.0          62     7.85
# 63679          0.0                    800.0          62     9.45
# 63680          0.0                    800.0          62     8.45
# 56346          4.0                    800.0          32    11.65
# 63695          2.0                    800.0          32     9.45
# ...            ...                      ...         ...      ...
# 47205          0.0                    800.0          62    30.05
# 36292          1.0                   3500.0          30    32.05
# 44294          5.0                   3500.0          30    32.05
# 36252          5.0                    800.0          38    31.05
# 47293          7.0                   1250.0          35    28.05
#
#                            dewpoint
# 63681 1969-12-31 23:59:59.999999984
# 63679 1969-12-31 23:59:59.999999985
# 63680 1969-12-31 23:59:59.999999985
# 56346 1969-12-31 23:59:59.999999986
# 63695 1969-12-31 23:59:59.999999987
# ...                             ...
# 47205 1970-01-01 00:00:00.000000025
# 36292 1970-01-01 00:00:00.000000025
# 44294 1970-01-01 00:00:00.000000025
# 36252 1970-01-01 00:00:00.000000025
# 47293 1970-01-01 00:00:00.000000025
#
# [1582 rows x 19 columns]
# No outliers detected in char_pressure_tendency
# No outliers detected in wind_direction
# Outliers in wind_speed:
#                      date  idstazione    lon    lat  altezza  pressure  \
# 48834 2019-02-23 06:00:00       16253  14.07  41.05       10  101940.0
# 63683 2023-02-05 01:00:00       16253  14.08  41.06       10  102560.0
# 63698 2023-02-05 16:00:00       16253  14.08  41.06       10  102600.0
# 63681 2023-02-04 23:00:00       16253  14.08  41.06       10  102460.0
# 57058 2022-03-08 14:00:00       16253  14.07  41.05       10  101400.0
# ...                   ...         ...    ...    ...      ...       ...
# 67319 2023-07-25 17:00:00       16253  14.08  41.06       10  100250.0
# 67318 2023-07-25 16:00:00       16253  14.08  41.06       10  100210.0
# 67316 2023-07-25 14:00:00       16253  14.08  41.06       10  100210.0
# 49756 2019-07-09 12:00:00       16253  14.07  41.05       10  101370.0
# 67317 2023-07-25 15:00:00       16253  14.08  41.06       10  100210.0
#
#        three_hour_pressure_change  char_pressure_tendency  wind_direction  \
# 48834                       160.0                     3.0            20.0
# 63683                       170.0                     2.0           320.0
# 63698                        50.0                     2.0           360.0
# 63681                       270.0                     1.0           360.0
# 57058                       -20.0                     6.0           360.0
# ...                           ...                     ...             ...
# 67319                        40.0                     3.0           220.0
# 67318                       -20.0                     6.0           220.0
# 67316                      -190.0                     6.0           180.0
# 49756                       140.0                     1.0           240.0
# 67317                      -100.0                     6.0           210.0
#
#        wind_speed  visibility  present_weather  past_weather1  past_weather2  \
# 48834     21.3818     25000.0              2.0            1.0            1.0
# 63683     15.5504     20000.0              2.0            1.0            1.0
# 63698     15.5504     30000.0              2.0            1.0            1.0
# 63681     17.4942     20000.0              2.0            1.0            1.0
# 57058     19.4380     30000.0              2.0            1.0            1.0
# ...           ...         ...              ...            ...            ...
# 67319     15.5504     20000.0              2.0            1.0            1.0
# 67318     17.4942     20000.0              2.0            1.0            1.0
# 67316     15.5504     20000.0              2.0            1.0            1.0
# 49756     17.4942      6000.0             10.0            2.0            2.0
# 67317     15.5504     12000.0              2.0            1.0            1.0
#
#        cloud_cover  height_of_base_of_cloud  cloud_type  drybulb  \
# 48834          1.0                    800.0          32     6.05
# 63683          0.0                    800.0          62     6.85
# 63698          2.0                    800.0          32     7.05
# 63681          0.0                    800.0          62     7.85
# 57058          4.0                    800.0          38     8.85
# ...            ...                      ...         ...      ...
# 67319          2.0                    800.0          31    29.85
# 67318          2.0                    800.0          31    31.45
# 67316          2.0                   8000.0          30    33.25
# 49756          8.0                    450.0          38    30.25
# 67317          4.0                    800.0          31    32.25
#
#                            dewpoint
# 48834 1969-12-31 23:59:59.999999980
# 63683 1969-12-31 23:59:59.999999983
# 63698 1969-12-31 23:59:59.999999983
# 63681 1969-12-31 23:59:59.999999984
# 57058 1969-12-31 23:59:59.999999985
# ...                             ...
# 67319 1970-01-01 00:00:00.000000027
# 67318 1970-01-01 00:00:00.000000027
# 67316 1970-01-01 00:00:00.000000027
# 49756 1970-01-01 00:00:00.000000028
# 67317 1970-01-01 00:00:00.000000030
#
# [1326 rows x 19 columns]
# Outliers in visibility:
#                      date  idstazione    lon    lat  altezza  pressure  \
# 57060 2022-03-08 16:00:00       16253  14.07  41.05       10  101500.0
# 57061 2022-03-08 17:00:00       16253  14.07  41.05       10  101520.0
# 57059 2022-03-08 15:00:00       16253  14.07  41.05       10  101420.0
# 53241 2021-03-01 15:00:00       16253  14.07  41.05       10  102560.0
# 53240 2021-03-01 12:00:00       16253  14.07  41.05       10  102660.0
# ...                   ...         ...    ...    ...      ...       ...
# 36467 2014-08-25 12:00:00       16253  14.07  41.05       10  101600.0
# 36468 2014-08-25 15:00:00       16253  14.07  41.05       10  101580.0
# 36499 2014-08-29 12:00:00       16253  14.07  41.05       10  101390.0
# 36356 2014-08-11 15:00:00       16253  14.07  41.05       10  101390.0
# 36500 2014-08-29 15:00:00       16253  14.07  41.05       10  101350.0
#
#        three_hour_pressure_change  char_pressure_tendency  wind_direction  \
# 57060                       100.0                     3.0            10.0
# 57061                       120.0                     3.0           360.0
# 57059                         0.0                     5.0            10.0
# 53241                      -100.0                     6.0           100.0
# 53240                       -60.0                     8.0            10.0
# ...                           ...                     ...             ...
# 36467                        10.0                     0.0           250.0
# 36468                       -20.0                     6.0           260.0
# 36499                         0.0                     4.0           260.0
# 36356                       -10.0                     6.0           250.0
# 36500                       -40.0                     8.0           260.0
#
#        wind_speed  visibility  present_weather  past_weather1  past_weather2  \
# 57060     17.4942     40000.0              2.0            1.0            1.0
# 57061     15.5504     40000.0              2.0            1.0            1.0
# 57059     17.4942     40000.0              2.0            1.0            1.0
# 53241      1.9438     40000.0              2.0            1.0            1.0
# 53240      3.8876     40000.0              2.0            1.0            1.0
# ...           ...         ...              ...            ...            ...
# 36467      7.7752     50000.0              2.0            1.0            1.0
# 36468      9.7190     45000.0              2.0            1.0            1.0
# 36499      7.7752     40000.0              2.0            1.0            1.0
# 36356      9.7190     40000.0              2.0            1.0            1.0
# 36500      9.7190     40000.0              2.0            1.0            1.0
#
#        cloud_cover  height_of_base_of_cloud  cloud_type  drybulb  \
# 57060          2.0                   1750.0          32     7.85
# 57061          2.0                    800.0          31     6.85
# 57059          4.0                    800.0          38     8.45
# 53241          0.0                    800.0          62    17.85
# 53240          0.0                    800.0          62    16.25
# ...            ...                      ...         ...      ...
# 36467          4.0                    450.0          31    30.45
# 36468          2.0                    450.0          31    28.85
# 36499          3.0                    800.0          31    32.25
# 36356          3.0                   8000.0          30    32.25
# 36500          2.0                    800.0          31    30.65
#
#                            dewpoint
# 57060 1969-12-31 23:59:59.999999986
# 57061 1969-12-31 23:59:59.999999987
# 57059 1969-12-31 23:59:59.999999987
# 53241 1969-12-31 23:59:59.999999991
# 53240 1969-12-31 23:59:59.999999991
# ...                             ...
# 36467 1970-01-01 00:00:00.000000023
# 36468 1970-01-01 00:00:00.000000023
# 36499 1970-01-01 00:00:00.000000024
# 36356 1970-01-01 00:00:00.000000025
# 36500 1970-01-01 00:00:00.000000026
#
# [123 rows x 19 columns]
# Outliers in present_weather:
#                      date  idstazione    lon    lat  altezza  pressure  \
# 50952 2020-03-28 03:00:00       16253  14.07  41.05       10  101130.0
# 64042 2023-02-20 02:00:00       16253  14.08  41.06       10  102300.0
# 56955 2022-02-27 06:00:00       16253  14.07  41.05       10  101300.0
# 48835 2019-02-23 09:00:00       16253  14.07  41.05       10  102200.0
# 48836 2019-02-23 12:00:00       16253  14.07  41.05       10  102100.0
# ...                   ...         ...    ...    ...      ...       ...
# 38972 2015-07-07 12:00:00       16253  14.07  41.05       10  101600.0
# 39100 2015-07-23 12:00:00       16253  14.07  41.05       10  100860.0
# 39101 2015-07-23 15:00:00       16253  14.07  41.05       10  100830.0
# 39229 2015-08-08 15:00:00       16253  14.07  41.05       10  101190.0
# 49750 2019-07-08 18:00:00       16253  14.07  41.05       10  101100.0
#
#        three_hour_pressure_change  char_pressure_tendency  wind_direction  \
# 50952                       -50.0                     8.0            10.0
# 64042                         0.0                     4.0           300.0
# 56955                       110.0                     3.0           340.0
# 48835                       260.0                     1.0            40.0
# 48836                      -100.0                     5.0            20.0
# ...                           ...                     ...             ...
# 38972                       -70.0                     7.0           260.0
# 39100                      -130.0                     7.0           250.0
# 39101                       -20.0                     5.0            70.0
# 39229                      -130.0                     6.0           260.0
# 49750                        20.0                     3.0           250.0
#
#        wind_speed  visibility  present_weather  past_weather1  past_weather2  \
# 50952      5.8314     12000.0             60.0            6.0            6.0
# 64042      3.8876      8000.0             10.0            2.0            2.0
# 56955     13.6066     20000.0              1.0            6.0            1.0
# 48835     23.3256      7000.0             10.0            1.0            1.0
# 48836     15.5504      9000.0             10.0            1.0            1.0
# ...           ...         ...              ...            ...            ...
# 38972      9.7190      7000.0             10.0            0.0            0.0
# 39100      9.7190      8000.0             10.0            0.0            0.0
# 39101      9.7190      7000.0             16.0            0.0            0.0
# 39229      7.7752      6000.0             21.0            9.0            6.0
# 49750      7.7752      8000.0             10.0            1.0            1.0
#
#        cloud_cover  height_of_base_of_cloud  cloud_type  drybulb  \
# 50952          7.0                    800.0          32    10.05
# 64042          5.0                    800.0          35     9.05
# 56955          2.0                   1750.0          32     7.45
# 48835          6.0                    800.0          32     3.25
# 48836          3.0                   1250.0          35     3.65
# ...            ...                      ...         ...      ...
# 38972          2.0                    800.0          31    31.45
# 39100          1.0                    800.0          31    33.85
# 39101          6.0                    450.0          39    31.65
# 39229          6.0                    450.0          39    32.05
# 49750          6.0                    800.0          31    32.85
#
#                            dewpoint
# 50952 1969-12-31 23:59:59.999999971
# 64042 1969-12-31 23:59:59.999999971
# 56955 1969-12-31 23:59:59.999999993
# 48835 1969-12-31 23:59:59.999999993
# 48836 1969-12-31 23:59:59.999999994
# ...                             ...
# 38972 1970-01-01 00:00:00.000000028
# 39100 1970-01-01 00:00:00.000000029
# 39101 1970-01-01 00:00:00.000000029
# 39229 1970-01-01 00:00:00.000000031
# 49750 1970-01-01 00:00:00.000000031
#
# [7560 rows x 19 columns]
# Outliers in past_weather1:
#                      date  idstazione    lon    lat  altezza  pressure  \
# 50952 2020-03-28 03:00:00       16253  14.07  41.05       10  101130.0
# 64042 2023-02-20 02:00:00       16253  14.08  41.06       10  102300.0
# 56955 2022-02-27 06:00:00       16253  14.07  41.05       10  101300.0
# 56333 2022-02-01 03:00:00       16253  14.07  41.05       10   99900.0
# 42997 2017-01-06 12:00:00       16253  14.07  41.05       10  101800.0
# ...                   ...         ...    ...    ...      ...       ...
# 49756 2019-07-09 12:00:00       16253  14.07  41.05       10  101370.0
# 38972 2015-07-07 12:00:00       16253  14.07  41.05       10  101600.0
# 39100 2015-07-23 12:00:00       16253  14.07  41.05       10  100860.0
# 39101 2015-07-23 15:00:00       16253  14.07  41.05       10  100830.0
# 39229 2015-08-08 15:00:00       16253  14.07  41.05       10  101190.0
#
#        three_hour_pressure_change  char_pressure_tendency  wind_direction  \
# 50952                       -50.0                     8.0            10.0
# 64042                         0.0                     4.0           300.0
# 56955                       110.0                     3.0           340.0
# 56333                        30.0                     1.0            20.0
# 42997                       -60.0                     8.0            10.0
# ...                           ...                     ...             ...
# 49756                       140.0                     1.0           240.0
# 38972                       -70.0                     7.0           260.0
# 39100                      -130.0                     7.0           250.0
# 39101                       -20.0                     5.0            70.0
# 39229                      -130.0                     6.0           260.0
#
#        wind_speed  visibility  present_weather  past_weather1  past_weather2  \
# 50952      5.8314     12000.0             60.0            6.0            6.0
# 64042      3.8876      8000.0             10.0            2.0            2.0
# 56955     13.6066     20000.0              1.0            6.0            1.0
# 56333     17.4942     10000.0             21.0            6.0            2.0
# 42997     17.4942     25000.0              1.0            7.0            1.0
# ...           ...         ...              ...            ...            ...
# 49756     17.4942      6000.0             10.0            2.0            2.0
# 38972      9.7190      7000.0             10.0            0.0            0.0
# 39100      9.7190      8000.0             10.0            0.0            0.0
# 39101      9.7190      7000.0             16.0            0.0            0.0
# 39229      7.7752      6000.0             21.0            9.0            6.0
#
#        cloud_cover  height_of_base_of_cloud  cloud_type  drybulb  \
# 50952          7.0                    800.0          32    10.05
# 64042          5.0                    800.0          35     9.05
# 56955          2.0                   1750.0          32     7.45
# 56333          6.0                   1250.0          34     9.05
# 42997          3.0                    800.0          32     3.25
# ...            ...                      ...         ...      ...
# 49756          8.0                    450.0          38    30.25
# 38972          2.0                    800.0          31    31.45
# 39100          1.0                    800.0          31    33.85
# 39101          6.0                    450.0          39    31.65
# 39229          6.0                    450.0          39    32.05
#
#                            dewpoint
# 50952 1969-12-31 23:59:59.999999971
# 64042 1969-12-31 23:59:59.999999971
# 56955 1969-12-31 23:59:59.999999993
# 56333 1969-12-31 23:59:59.999999995
# 42997 1969-12-31 23:59:59.999999995
# ...                             ...
# 49756 1970-01-01 00:00:00.000000028
# 38972 1970-01-01 00:00:00.000000028
# 39100 1970-01-01 00:00:00.000000029
# 39101 1970-01-01 00:00:00.000000029
# 39229 1970-01-01 00:00:00.000000031
#
# [7637 rows x 19 columns]
# Outliers in past_weather2:
#                      date  idstazione    lon    lat  altezza  pressure  \
# 50952 2020-03-28 03:00:00       16253  14.07  41.05       10  101130.0
# 64042 2023-02-20 02:00:00       16253  14.08  41.06       10  102300.0
# 56333 2022-02-01 03:00:00       16253  14.07  41.05       10   99900.0
# 64370 2023-03-15 18:00:00       16253  14.08  41.06       10  100720.0
# 56336 2022-02-01 06:00:00       16253  14.07  41.05       10  100100.0
# ...                   ...         ...    ...    ...      ...       ...
# 49756 2019-07-09 12:00:00       16253  14.07  41.05       10  101370.0
# 38972 2015-07-07 12:00:00       16253  14.07  41.05       10  101600.0
# 39100 2015-07-23 12:00:00       16253  14.07  41.05       10  100860.0
# 39101 2015-07-23 15:00:00       16253  14.07  41.05       10  100830.0
# 39229 2015-08-08 15:00:00       16253  14.07  41.05       10  101190.0
#
#        three_hour_pressure_change  char_pressure_tendency  wind_direction  \
# 50952                       -50.0                     8.0            10.0
# 64042                         0.0                     4.0           300.0
# 56333                        30.0                     1.0            20.0
# 64370                       340.0                     2.0           340.0
# 56336                       200.0                     3.0           330.0
# ...                           ...                     ...             ...
# 49756                       140.0                     1.0           240.0
# 38972                       -70.0                     7.0           260.0
# 39100                      -130.0                     7.0           250.0
# 39101                       -20.0                     5.0            70.0
# 39229                      -130.0                     6.0           260.0
#
#        wind_speed  visibility  present_weather  past_weather1  past_weather2  \
# 50952      5.8314     12000.0             60.0            6.0            6.0
# 64042      3.8876      8000.0             10.0            2.0            2.0
# 56333     17.4942     10000.0             21.0            6.0            2.0
# 64370     11.6628     15000.0              2.0            6.0            2.0
# 56336     17.4942     10000.0              1.0            6.0            2.0
# ...           ...         ...              ...            ...            ...
# 49756     17.4942      6000.0             10.0            2.0            2.0
# 38972      9.7190      7000.0             10.0            0.0            0.0
# 39100      9.7190      8000.0             10.0            0.0            0.0
# 39101      9.7190      7000.0             16.0            0.0            0.0
# 39229      7.7752      6000.0             21.0            9.0            6.0
#
#        cloud_cover  height_of_base_of_cloud  cloud_type  drybulb  \
# 50952          7.0                    800.0          32    10.05
# 64042          5.0                    800.0          35     9.05
# 56333          6.0                   1250.0          34     9.05
# 64370          5.0                    800.0          32    12.25
# 56336          7.0                   1750.0          34     8.05
# ...            ...                      ...         ...      ...
# 49756          8.0                    450.0          38    30.25
# 38972          2.0                    800.0          31    31.45
# 39100          1.0                    800.0          31    33.85
# 39101          6.0                    450.0          39    31.65
# 39229          6.0                    450.0          39    32.05
#
#                            dewpoint
# 50952 1969-12-31 23:59:59.999999971
# 64042 1969-12-31 23:59:59.999999971
# 56333 1969-12-31 23:59:59.999999995
# 64370 1969-12-31 23:59:59.999999996
# 56336 1969-12-31 23:59:59.999999996
# ...                             ...
# 49756 1970-01-01 00:00:00.000000028
# 38972 1970-01-01 00:00:00.000000028
# 39100 1970-01-01 00:00:00.000000029
# 39101 1970-01-01 00:00:00.000000029
# 39229 1970-01-01 00:00:00.000000031
#
# [7105 rows x 19 columns]
# No outliers detected in cloud_cover
# Outliers in height_of_base_of_cloud:
#                      date  idstazione    lon    lat  altezza  pressure  \
# 65363 2023-04-27 09:00:00       16253  14.08  41.06       10  101660.0
# 56275 2022-01-29 17:00:00       16253  14.07  41.05       10  102580.0
# 56998 2022-03-01 02:00:00       16253  14.07  41.05       10  102160.0
# 56274 2022-01-29 16:00:00       16253  14.07  41.05       10  102580.0
# 57001 2022-03-01 05:00:00       16253  14.07  41.05       10  102110.0
# ...                   ...         ...    ...    ...      ...       ...
# 38974 2015-07-07 18:00:00       16253  14.07  41.05       10  101380.0
# 38966 2015-07-06 18:00:00       16253  14.07  41.05       10  101700.0
# 44416 2017-07-13 18:00:00       16253  14.07  41.05       10  100990.0
# 41843 2016-07-11 18:00:00       16253  14.07  41.05       10  101220.0
# 44584 2017-08-03 18:00:00       16253  14.07  41.05       10  101310.0
#
#        three_hour_pressure_change  char_pressure_tendency  wind_direction  \
# 65363                         NaN                     NaN           360.0
# 56275                        20.0                     4.0           330.0
# 56998                       -50.0                     8.0           360.0
# 56274                       -60.0                     6.0            30.0
# 57001                       -50.0                     6.0           360.0
# ...                           ...                     ...             ...
# 38974                      -100.0                     7.0           230.0
# 38966                       -30.0                     5.0           280.0
# 44416                       -10.0                     8.0           240.0
# 41843                       -60.0                     7.0           260.0
# 44584                       -80.0                     6.0           260.0
#
#        wind_speed  visibility  present_weather  past_weather1  past_weather2  \
# 65363      1.9438        50.0              2.0            1.0            1.0
# 56275      7.7752     15000.0              2.0            1.0            1.0
# 56998      0.0000     25000.0              2.0            1.0            1.0
# 56274      5.8314     20000.0              2.0            1.0            1.0
# 57001      0.0000     25000.0              2.0            1.0            1.0
# ...           ...         ...              ...            ...            ...
# 38974      5.8314     15000.0              2.0            1.0            1.0
# 38966      9.7190     12000.0              2.0            1.0            1.0
# 44416      9.7190     10000.0              2.0            1.0            1.0
# 41843      5.8314     20000.0              2.0            1.0            1.0
# 44584      5.8314     22000.0              2.0            1.0            1.0
#
#        cloud_cover  height_of_base_of_cloud  cloud_type  drybulb  \
# 65363          1.0                   8000.0          30    18.85
# 56275          1.0                   2250.0          30     7.85
# 56998          3.0                   2250.0          30     6.25
# 56274          1.0                   2250.0          30    11.25
# 57001          2.0                   2250.0          30     4.65
# ...            ...                      ...         ...      ...
# 38974          3.0                   3500.0          30    27.45
# 38966          1.0                   3500.0          30    28.45
# 44416          3.0                   8000.0          30    30.05
# 41843          3.0                   3500.0          30    29.05
# 44584          2.0                   2250.0          30    30.05
#
#                            dewpoint
# 65363 1969-12-31 23:59:59.999999971
# 56275 1969-12-31 23:59:59.999999983
# 56998 1969-12-31 23:59:59.999999985
# 56274 1969-12-31 23:59:59.999999986
# 57001 1969-12-31 23:59:59.999999987
# ...                             ...
# 38974 1970-01-01 00:00:00.000000027
# 38966 1970-01-01 00:00:00.000000028
# 44416 1970-01-01 00:00:00.000000028
# 41843 1970-01-01 00:00:00.000000028
# 44584 1970-01-01 00:00:00.000000029
#
# [5968 rows x 19 columns]
# No outliers detected in cloud_type
# Outliers in drybulb:
#                      date  idstazione    lon    lat  altezza  pressure  \
# 58814 2022-06-27 14:00:00       16253  14.08  41.06       10  101400.0
# 39052 2015-07-17 12:00:00       16253  14.07  41.05       10  101720.0
# 39228 2015-08-08 12:00:00       16253  14.07  41.05       10  101370.0
#
#        three_hour_pressure_change  char_pressure_tendency  wind_direction  \
# 58814                       -80.0                     6.0           180.0
# 39052                       -10.0                     8.0           270.0
# 39228                       -30.0                     8.0           250.0
#
#        wind_speed  visibility  present_weather  past_weather1  past_weather2  \
# 58814      7.7752     12000.0              2.0            1.0            1.0
# 39052      7.7752     15000.0              2.0            1.0            1.0
# 39228      5.8314     20000.0              2.0            1.0            1.0
#
#        cloud_cover  height_of_base_of_cloud  cloud_type  drybulb  \
# 58814          0.0                    800.0          62    38.65
# 39052          0.0                    800.0          62    39.45
# 39228          0.0                    800.0          62    39.05
#
#                            dewpoint
# 58814 1970-01-01 00:00:00.000000009
# 39052 1970-01-01 00:00:00.000000020
# 39228 1970-01-01 00:00:00.000000022

# %%
# Categorical Variables EDA
# idstazione
plt.figure(figsize=(10, 6))
sns.countplot(x='idstazione', data=Airport1)
plt.title('Frequency Distribution of Station IDs')
plt.xticks(rotation=90)
plt.show()

# %%
# char_pressure_tendency
plt.figure(figsize=(10, 6))
sns.countplot(x='char_pressure_tendency', data=Airport1)
plt.title('Frequency Distribution of Pressure Tendency')
plt.xticks(rotation=90)
plt.show()

# %%
# wind_direction
plt.figure(figsize=(10, 6))
sns.countplot(x='wind_direction', data=Airport1)
plt.title('Frequency Distribution of Wind Directions')
plt.xticks(rotation=90)
plt.show()

# %%
# Polar plot / Wind rose plot for wind_direction (example using matplotlib)
wind_dir_counts = Airport1['wind_direction'].value_counts().sort_index()
angles = np.linspace(0, 2 * np.pi, len(wind_dir_counts), endpoint=False).tolist()
angles += angles[:1]
wind_dir_counts = wind_dir_counts.tolist()
wind_dir_counts += wind_dir_counts[:1]

fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))
ax.fill(angles, wind_dir_counts, color='blue', alpha=0.25)
ax.plot(angles, wind_dir_counts, color='blue', linewidth=2)
ax.set_yticklabels([])
ax.set_xticks(angles[:-1])
ax.set_xticklabels(wind_dir_counts.index)
plt.title('Wind Rose Plot for Wind Directions')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in set_ticklabels(self, labels, minor, fontdict, **kwargs)
#    1958         try:
# -> 1959             labels = [t.get_text() if hasattr(t, 'get_text') else t
#    1960                       for t in labels]
#
# TypeError: 'builtin_function_or_method' object is not iterable
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-61a501ea5835> in <cell line: 13>()
#      11 ax.set_yticklabels([])
#      12 ax.set_xticks(angles[:-1])
# ---> 13 ax.set_xticklabels(wind_dir_counts.index)
#      14 plt.title('Wind Rose Plot for Wind Directions')
#      15 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_base.py in wrapper(self, *args, **kwargs)
#      72
#      73         def wrapper(self, *args, **kwargs):
# ---> 74             return get_method(self)(*args, **kwargs)
#      75
#      76         wrapper.__module__ = owner.__module__
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     295                 f"for the old name will be dropped %(removal)s.")
#     296             kwargs[new] = kwargs.pop(old)
# --> 297         return func(*args, **kwargs)
#     298
#     299     # wrapper() must keep the same documented signature as func(): if we
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axis.py in set_ticklabels(self, labels, minor, fontdict, **kwargs)
#    1960                       for t in labels]
#    1961         except TypeError:
# -> 1962             raise TypeError(f"{labels:=} must be a sequence") from None
#    1963         locator = (self.get_minor_locator() if minor
#    1964                    else self.get_major_locator())
#
# TypeError: unsupported format string passed to builtin_function_or_method.__format__

# %%
# present_weather, past_weather1, past_weather2, cloud_type
weather_columns = ['present_weather', 'past_weather1', 'past_weather2', 'cloud_type']
for col in weather_columns:
    plt.figure(figsize=(10, 6))
    sns.countplot(x=col, data=Airport1)
    plt.title(f'Frequency Distribution of {col}')
    plt.xticks(rotation=90)
    plt.show()

# %%
# Numerical Variables EDA
# lon (Longitude), lat (Latitude)
plt.figure(figsize=(10, 6))
sns.scatterplot(x='lon', y='lat', data=Airport1)
plt.title('Geographic Distribution of Stations')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
# Map visualization using GeoPandas
gdf = gpd.GeoDataFrame(Airport1, geometry=gpd.points_from_xy(Airport1.lon, Airport1.lat))
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
ax = world.plot(figsize=(15, 10))
gdf.plot(ax=ax, color='red', markersize=5)
plt.title('Map Visualization of Stations')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-ab551a9d319f> in <cell line: 2>()
#       1 # Map visualization using GeoPandas
# ----> 2 gdf = gpd.GeoDataFrame(Airport1, geometry=gpd.points_from_xy(Airport1.lon, Airport1.lat))
#       3 world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
#       4 ax = world.plot(figsize=(15, 10))
#       5 gdf.plot(ax=ax, color='red', markersize=5)
#
# NameError: name 'gpd' is not defined

# %%
# altezza (Altitude)
plt.figure(figsize=(10, 6))
sns.histplot(Airport1['altezza'], kde=True)
plt.title('Distribution of Altitude')
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(x='altezza', data=Airport1)
plt.title('Box Plot of Altitude')
plt.show()

print(Airport1['altezza'].describe())
# Out:
# count    35558.0
# mean        10.0
# std          0.0
# min         10.0
# 25%         10.0
# 50%         10.0
# 75%         10.0
# max         10.0
# Name: altezza, dtype: float64

# %%
# pressure
plt.figure(figsize=(10, 6))
sns.histplot(Airport1['pressure'], kde=True)
plt.title('Distribution of Pressure')
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(x='pressure', data=Airport1)
plt.title('Box Plot of Pressure')
plt.show()

# %%
# Time series plot for pressure (if timestamp exists)
# df['timestamp'] = pd.to_datetime(df['timestamp'])  # Assuming you have a timestamp column
# df.set_index('timestamp', inplace=True)
# df['pressure'].plot(figsize=(15, 5))
# plt.title('Time Series of Pressure')
# plt.show()

# three_hour_pressure_change
plt.figure(figsize=(10, 6))
sns.histplot(Airport1['three_hour_pressure_change'], kde=True)
plt.title('Distribution of Three Hour Pressure Change')
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(x='three_hour_pressure_change', data=Airport1)
plt.title('Box Plot of Three Hour Pressure Change')
plt.show()

# Line plot of pressure changes over time (if timestamp exists)
# df['three_hour_pressure_change'].plot(figsize=(15, 5))
# plt.title('Three Hour Pressure Change Over Time')
# plt.show()

# wind_speed
plt.figure(figsize=(10, 6))
sns.histplot(Airport1['wind_speed'], kde=True)
plt.title('Distribution of Wind Speed')
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(x='wind_speed', data=Airport1)
plt.title('Box Plot of Wind Speed')
plt.show()

# %%
# Time series plot to observe wind speed trends (if timestamp exists)
# df['wind_speed'].plot(figsize=(15, 5))
# plt.title('Time Series of Wind Speed')
# plt.show()

# visibility
plt.figure(figsize=(10, 6))
sns.histplot(Airport1['visibility'], kde=True)
plt.title('Distribution of Visibility')
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(x='visibility', data=Airport1)
plt.title('Box Plot of Visibility')
plt.show()

print(Airport1['visibility'].describe())
# Out:
# count    35558.000000
# mean     14943.663873
# std       6884.662477
# min         50.000000
# 25%      10000.000000
# 50%      15000.000000
# 75%      20000.000000
# max      75000.000000
# Name: visibility, dtype: float64

# %%
# cloud_cover
plt.figure(figsize=(10, 6))
sns.histplot(Airport1['cloud_cover'], kde=True)
plt.title('Distribution of Cloud Cover')
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(x='cloud_cover', data=Airport1)
plt.title('Box Plot of Cloud Cover')
plt.show()

print(Airport1['cloud_cover'].describe())
# Out:
# count    35545.000000
# mean         3.453735
# std          2.785095
# min          0.000000
# 25%          0.000000
# 50%          3.000000
# 75%          6.000000
# max          8.000000
# Name: cloud_cover, dtype: float64

# %%
# height_of_base_of_cloud
plt.figure(figsize=(10, 6))
sns.histplot(Airport1['height_of_base_of_cloud'], kde=True)
plt.title('Distribution of Height of Base of Cloud')
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(x='height_of_base_of_cloud', data=Airport1)
plt.title('Box Plot of Height of Base of Cloud')
plt.show()

print(Airport1['height_of_base_of_cloud'].describe())
# Out:
# count    35558.000000
# mean      1494.933348
# std       1871.690623
# min         30.000000
# 25%        800.000000
# 50%        800.000000
# 75%       1250.000000
# max       8000.000000
# Name: height_of_base_of_cloud, dtype: float64

# %%
# drybulb (Dry Bulb Temperature), dewpoint (Dew Point Temperature)
plt.figure(figsize=(10, 6))
sns.histplot(Airport1['drybulb'], kde=True)
plt.title('Distribution of Dry Bulb Temperature')
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(x='drybulb', data=Airport1)
plt.title('Box Plot of Dry Bulb Temperature')
plt.show()

plt.figure(figsize=(10, 6))
sns.histplot(Airport1['dewpoint'], kde=True)
plt.title('Distribution of Dew Point Temperature')
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(x='dewpoint', data=Airport1)
plt.title('Box Plot of Dew Point Temperature')
plt.show()

# %%
# Line plots to observe temperature trends (if timestamp exists)
# df['drybulb'].plot(figsize=(15, 5))
# plt.title('Time Series of Dry Bulb Temperature')
# plt.show()

# df['dewpoint'].plot(figsize=(15, 5))
# plt.title('Time Series of Dew Point Temperature')
# plt.show()

# Scatter plot of drybulb vs dewpoint
plt.figure(figsize=(10, 6))
sns.scatterplot(x='drybulb', y='dewpoint', data=Airport1)
plt.title('Dry Bulb Temperature vs Dew Point Temperature')
plt.xlabel('Dry Bulb Temperature')
plt.ylabel('Dew Point Temperature')
plt.show()

# %%
pip install geopandas
# Out:
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (0.13.2)
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.9.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas) (24.0)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.3)
# Requirement already satisfied: pyproj>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.4)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (23.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (2024.2.2)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (1.25.2)

# %% [markdown]
# Arima and Sarima Model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from sklearn.metrics import mean_squared_error

# %%
# Ensure the timestamp column is parsed as datetime
Airport1['timestamp'] = pd.to_datetime(Airport1['timestamp'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'timestamp'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-80-006a3b1f097c> in <cell line: 2>()
#       1 # Ensure the timestamp column is parsed as datetime
# ----> 2 Airport1['timestamp'] = pd.to_datetime(Airport1['timestamp'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3759             if self.columns.nlevels > 1:
#    3760                 return self._getitem_multilevel(key)
# -> 3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#    3763                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'timestamp'

# %%
# Visualize the time series data
plt.figure(figsize=(12, 6))
plt.plot(Airport1['pressure'])
plt.title('Time Series of Pressure')
plt.xlabel('Date')
plt.ylabel('Pressure')
plt.show()
